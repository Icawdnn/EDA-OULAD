# %% [markdown]
# 202010370311220 - Ica Wahyu Diana - Analisis Big Data C

# %% [markdown]
# ### Pre Processing dan EDA

# %%
#Importing Libary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
assessments = pd.read_csv('assessments.csv')
courses = pd.read_csv('courses.csv')
studentInfo = pd.read_csv('studentInfo.csv')
studentRegistration = pd.read_csv('studentRegistration.csv')
studentAssessment = pd.read_csv('studentAssessment.csv')
vle = pd.read_csv('vle.csv')
# studentVle = pd.read_csv('studentVle.csv')

# %% [markdown]
# ### Assessments

# %%
assessments.head()
# Out:
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0

# %%
assessments.describe()
# Out:
#        id_assessment        date      weight
# count     206.000000  195.000000  206.000000
# mean    26473.975728  145.005128   20.873786
# std     10098.625521   76.001119   30.384224
# min      1752.000000   12.000000    0.000000
# 25%     15023.250000   71.000000    0.000000
# 50%     25364.500000  152.000000   12.500000
# 75%     34891.750000  222.000000   24.250000
# max     40088.000000  261.000000  100.000000

# %%
assessments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        206 non-null    object
#  1   code_presentation  206 non-null    object
#  2   id_assessment      206 non-null    int64
#  3   assessment_type    206 non-null    object
#  4   date               195 non-null    float64
#  5   weight             206 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.8+ KB

# %%
#Label Encoding
labelencoder = LabelEncoder()
assessments['code_module'] = labelencoder.fit_transform(assessments['code_module'])
assessments['code_presentation'] = labelencoder.fit_transform(assessments['code_presentation'])
assessments['assessment_type'] = labelencoder.fit_transform(assessments['assessment_type'])

# %%
assessments
# Out:
#      code_module  code_presentation  id_assessment  assessment_type   date  \
# 0              0                  1           1752                2   19.0
# 1              0                  1           1753                2   54.0
# 2              0                  1           1754                2  117.0
# 3              0                  1           1755                2  166.0
# 4              0                  1           1756                2  215.0
# ..           ...                ...            ...              ...    ...
# 201            6                  3          37443                0  229.0
# 202            6                  3          37435                2   61.0
# 203            6                  3          37436                2  124.0
# 204            6                  3          37437                2  173.0
# 205            6                  3          37444                1  229.0
#
#      weight
# 0      10.0
# 1      20.0
# 2      20.0
# 3      20.0
# ...

# %%
assessments.isnull().sum()
# Out:
# code_module           0
# code_presentation     0
# id_assessment         0
# assessment_type       0
# date                 11
# weight                0
# dtype: int64

# %%
data_clean = assessments.dropna(axis=1)

# %%
data_clean
# Out:
#      code_module  code_presentation  id_assessment  assessment_type  weight
# 0              0                  1           1752                2    10.0
# 1              0                  1           1753                2    20.0
# 2              0                  1           1754                2    20.0
# 3              0                  1           1755                2    20.0
# 4              0                  1           1756                2    30.0
# ..           ...                ...            ...              ...     ...
# 201            6                  3          37443                0     0.0
# 202            6                  3          37435                2     0.0
# 203            6                  3          37436                2     0.0
# 204            6                  3          37437                2     0.0
# 205            6                  3          37444                1   100.0
#
# [206 rows x 5 columns]

# %% [markdown]
# ### Courses

# %%
courses.head()
# Out:
#   code_module code_presentation  module_presentation_length
# 0         AAA             2013J                         268
# 1         AAA             2014J                         269
# 2         BBB             2013J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240

# %%
courses.describe()
# Out:
#        module_presentation_length
# count                   22.000000
# mean                   255.545455
# std                     13.654677
# min                    234.000000
# 25%                    241.000000
# 50%                    261.500000
# 75%                    268.000000
# max                    269.000000

# %%
courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   code_module                 22 non-null     object
#  1   code_presentation           22 non-null     object
#  2   module_presentation_length  22 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 656.0+ bytes

# %%
#Label Encoding
labelencoder = LabelEncoder()
courses['code_module'] = labelencoder.fit_transform(courses['code_module'])
courses['code_presentation'] = labelencoder.fit_transform(courses['code_presentation'])

# %%
courses
# Out:
#     code_module  code_presentation  module_presentation_length
# 0             0                  1                         268
# 1             0                  3                         269
# 2             1                  1                         268
# 3             1                  3                         262
# 4             1                  0                         240
# 5             1                  2                         234
# 6             2                  3                         269
# 7             2                  2                         241
# 8             3                  1                         261
# 9             3                  3                         262
# 10            3                  0                         240
# 11            3                  2                         241
# 12            4                  1                         268
# 13            4                  3                         269
# ...

# %%
courses.isnull().sum()
# Out:
# code_module                   0
# code_presentation             0
# module_presentation_length    0
# dtype: int64

# %% [markdown]
# ### StudentInfo

# %%
studentInfo.head()
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# ...

# %%
studentInfo.describe()
# Out:
#          id_student  num_of_prev_attempts  studied_credits
# count  3.259300e+04          32593.000000     32593.000000
# mean   7.066877e+05              0.163225        79.758691
# std    5.491673e+05              0.479758        41.071900
# min    3.733000e+03              0.000000        30.000000
# 25%    5.085730e+05              0.000000        60.000000
# 50%    5.903100e+05              0.000000        60.000000
# 75%    6.444530e+05              0.000000       120.000000
# max    2.716795e+06              6.000000       655.000000

# %%
studentInfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           32593 non-null  object
#  1   code_presentation     32593 non-null  object
#  2   id_student            32593 non-null  int64
#  3   gender                32593 non-null  object
#  4   region                32593 non-null  object
#  5   highest_education     32593 non-null  object
#  6   imd_band              31482 non-null  object
#  7   age_band              32593 non-null  object
#  8   num_of_prev_attempts  32593 non-null  int64
#  9   studied_credits       32593 non-null  int64
#  10  disability            32593 non-null  object
#  11  final_result          32593 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB

# %%
studentInfo.isnull().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# gender                     0
# region                     0
# highest_education          0
# imd_band                1111
# age_band                   0
# num_of_prev_attempts       0
# studied_credits            0
# disability                 0
# final_result               0
# dtype: int64

# %%
data_clean = studentInfo.dropna(axis=1)

# %%
data_clean
# Out:
#       code_module code_presentation  id_student gender                region  \
# 0             AAA             2013J       11391      M   East Anglian Region
# 1             AAA             2013J       28400      F              Scotland
# 2             AAA             2013J       30268      F  North Western Region
# 3             AAA             2013J       31604      F     South East Region
# 4             AAA             2013J       32885      F  West Midlands Region
# ...           ...               ...         ...    ...                   ...
# 32588         GGG             2014J     2640965      F                 Wales
# 32589         GGG             2014J     2645731      F   East Anglian Region
# 32590         GGG             2014J     2648187      F          South Region
# 32591         GGG             2014J     2679821      F     South East Region
# 32592         GGG             2014J     2684003      F      Yorkshire Region
#
# ...

# %%
#Label Encoding
labelencoder = LabelEncoder()
studentInfo['code_module'] = labelencoder.fit_transform(studentInfo['code_module'])
studentInfo['code_presentation'] = labelencoder.fit_transform(studentInfo['code_presentation'])
studentInfo['gender'] = labelencoder.fit_transform(studentInfo['gender'])
studentInfo['region'] = labelencoder.fit_transform(studentInfo['region'])
studentInfo['highest_education'] = labelencoder.fit_transform(studentInfo['highest_education'])
studentInfo['imd_band'] = labelencoder.fit_transform(studentInfo['imd_band'])
studentInfo['age_band'] = labelencoder.fit_transform(studentInfo['age_band'])
studentInfo['disability'] = labelencoder.fit_transform(studentInfo['disability'])
studentInfo['final_result'] = labelencoder.fit_transform(studentInfo['final_result'])

# %%
studentInfo
# Out:
#        code_module  code_presentation  id_student  gender  region  \
# 0                0                  1       11391       1       0
# 1                0                  1       28400       0       6
# 2                0                  1       30268       0       5
# 3                0                  1       31604       0       7
# 4                0                  1       32885       0      11
# ...            ...                ...         ...     ...     ...
# 32588            6                  3     2640965       0      10
# 32589            6                  3     2645731       0       0
# 32590            6                  3     2648187       0       8
# 32591            6                  3     2679821       0       7
# 32592            6                  3     2684003       0      12
#
#        highest_education  imd_band  age_band  num_of_prev_attempts  \
# 0                      1         9         2                     0
# ...

# %% [markdown]
# ### StudentRegistration

# %%
studentRegistration.head()
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN

# %%
studentRegistration.describe()
# Out:
#          id_student  date_registration  date_unregistration
# count  3.259300e+04       32548.000000         10072.000000
# mean   7.066877e+05         -69.411300            49.757645
# std    5.491673e+05          49.260522            82.460890
# min    3.733000e+03        -322.000000          -365.000000
# 25%    5.085730e+05        -100.000000            -2.000000
# 50%    5.903100e+05         -57.000000            27.000000
# 75%    6.444530e+05         -29.000000           109.000000
# max    2.716795e+06         167.000000           444.000000

# %%
studentRegistration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   code_module          32593 non-null  object
#  1   code_presentation    32593 non-null  object
#  2   id_student           32593 non-null  int64
#  3   date_registration    32548 non-null  float64
#  4   date_unregistration  10072 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.2+ MB

# %%
studentRegistration.isnull().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# date_registration         45
# date_unregistration    22521
# dtype: int64

# %%
data_clean = studentRegistration.dropna(axis=1)

# %%
data_clean
# Out:
#       code_module code_presentation  id_student
# 0             AAA             2013J       11391
# 1             AAA             2013J       28400
# 2             AAA             2013J       30268
# 3             AAA             2013J       31604
# 4             AAA             2013J       32885
# ...           ...               ...         ...
# 32588         GGG             2014J     2640965
# 32589         GGG             2014J     2645731
# 32590         GGG             2014J     2648187
# 32591         GGG             2014J     2679821
# 32592         GGG             2014J     2684003
#
# [32593 rows x 3 columns]

# %%
# Label Encoding
labelencoder = LabelEncoder()
studentRegistration['code_module'] = labelencoder.fit_transform(studentRegistration['code_module'])
studentRegistration['code_presentation'] = labelencoder.fit_transform(studentRegistration['code_presentation'])
studentRegistration['date_registration'] = labelencoder.fit_transform(studentRegistration['date_registration'])
studentRegistration['date_unregistration'] = labelencoder.fit_transform(studentRegistration['date_unregistration'])

# %%
studentRegistration
# Out:
#        code_module  code_presentation  id_student  date_registration  \
# 0                0                  1       11391                135
# 1                0                  1       28400                241
# 2                0                  1       30268                202
# 3                0                  1       31604                242
# 4                0                  1       32885                118
# ...            ...                ...         ...                ...
# 32588            6                  3     2640965                290
# 32589            6                  3     2645731                271
# 32590            6                  3     2648187                165
# 32591            6                  3     2679821                245
# 32592            6                  3     2684003                266
#
#        date_unregistration
# 0                      416
# 1                      416
# 2                      185
# ...

# %% [markdown]
# ### StudentVle

# %%
studentVle.head()
# Out:
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1

# %%
studentVle.describe()
# Out:
#          id_student       id_site          date     sum_click
# count  3.226274e+06  3.226274e+06  3.226274e+06  3.226274e+06
# mean   7.544178e+05  7.638597e+05  9.426702e+01  3.538557e+00
# std    6.234189e+05  1.407627e+05  7.787942e+01  8.238812e+00
# min    6.516000e+03  5.427920e+05 -2.400000e+01  1.000000e+00
# 25%    4.923570e+05  7.037320e+05  2.200000e+01  1.000000e+00
# 50%    5.856930e+05  7.301040e+05  8.200000e+01  2.000000e+00
# 75%    6.497420e+05  9.090870e+05  1.580000e+02  3.000000e+00
# max    2.698588e+06  1.049562e+06  2.690000e+02  2.853000e+03

# %%
studentVle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226274 entries, 0 to 3226273
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   code_module        object
#  1   code_presentation  object
#  2   id_student         int64
#  3   id_site            int64
#  4   date               int64
#  5   sum_click          int64
# dtypes: int64(4), object(2)
# memory usage: 147.7+ MB

# %%
studentVle.isnull().sum()
# Out:
# code_module          0
# code_presentation    0
# id_student           0
# id_site              0
# date                 0
# sum_click            0
# dtype: int64

# %% [markdown]
# ### StudentAssessment

# %%
studentAssessment.head()
# Out:
#    id_assessment  id_student  date_submitted  is_banked  score
# 0           1752       11391              18          0   78.0
# 1           1752       28400              22          0   70.0
# 2           1752       31604              17          0   72.0
# 3           1752       32885              26          0   69.0
# 4           1752       38053              19          0   79.0

# %%
studentAssessment.describe()
# Out:
#        id_assessment    id_student  date_submitted      is_banked  \
# count  173912.000000  1.739120e+05   173912.000000  173912.000000
# mean    26553.803556  7.051507e+05      116.032942       0.010977
# std      8829.784254  5.523952e+05       71.484148       0.104194
# min      1752.000000  6.516000e+03      -11.000000       0.000000
# 25%     15022.000000  5.044290e+05       51.000000       0.000000
# 50%     25359.000000  5.852080e+05      116.000000       0.000000
# 75%     34883.000000  6.344980e+05      173.000000       0.000000
# max     37443.000000  2.698588e+06      608.000000       1.000000
#
#                score
# count  173739.000000
# mean       75.799573
# std        18.798107
# min         0.000000
# 25%        65.000000
# 50%        80.000000
# 75%        90.000000
# max       100.000000

# %%
studentAssessment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173912 entries, 0 to 173911
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_assessment   173912 non-null  int64
#  1   id_student      173912 non-null  int64
#  2   date_submitted  173912 non-null  int64
#  3   is_banked       173912 non-null  int64
#  4   score           173739 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 6.6 MB

# %%
studentAssessment.isnull().sum()
# Out:
# id_assessment       0
# id_student          0
# date_submitted      0
# is_banked           0
# score             173
# dtype: int64

# %%
data_clean = studentAssessment.dropna(axis=1)

# %%
data_clean
# Out:
#         id_assessment  id_student  date_submitted  is_banked
# 0                1752       11391              18          0
# 1                1752       28400              22          0
# 2                1752       31604              17          0
# 3                1752       32885              26          0
# 4                1752       38053              19          0
# ...               ...         ...             ...        ...
# 173907          37443      527538             227          0
# 173908          37443      534672             229          0
# 173909          37443      546286             215          0
# 173910          37443      546724             230          0
# 173911          37443      558486             224          0
#
# [173912 rows x 4 columns]

# %% [markdown]
# ### Vle

# %%
vle.head()
# Out:
#    id_site code_module code_presentation activity_type  week_from  week_to
# 0   546943         AAA             2013J      resource        NaN      NaN
# 1   546712         AAA             2013J     oucontent        NaN      NaN
# 2   546998         AAA             2013J      resource        NaN      NaN
# 3   546888         AAA             2013J           url        NaN      NaN
# 4   547035         AAA             2013J      resource        NaN      NaN

# %%
vle.describe()
# Out:
#             id_site    week_from      week_to
# count  6.364000e+03  1121.000000  1121.000000
# mean   7.260991e+05    15.204282    15.214987
# std    1.283151e+05     8.792865     8.779806
# min    5.267210e+05     0.000000     0.000000
# 25%    6.615928e+05     8.000000     8.000000
# 50%    7.300965e+05    15.000000    15.000000
# 75%    8.140162e+05    22.000000    22.000000
# max    1.077905e+06    29.000000    29.000000

# %%
vle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6364 entries, 0 to 6363
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_site            6364 non-null   int64
#  1   code_module        6364 non-null   object
#  2   code_presentation  6364 non-null   object
#  3   activity_type      6364 non-null   object
#  4   week_from          1121 non-null   float64
#  5   week_to            1121 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 298.4+ KB

# %%
vle.isnull().sum()
# Out:
# id_site                 0
# code_module             0
# code_presentation       0
# activity_type           0
# week_from            5243
# week_to              5243
# dtype: int64

# %%
data_clean = vle.dropna(axis=1)

# %%
data_clean
# Out:
#       id_site code_module code_presentation activity_type
# 0      546943         AAA             2013J      resource
# 1      546712         AAA             2013J     oucontent
# 2      546998         AAA             2013J      resource
# 3      546888         AAA             2013J           url
# 4      547035         AAA             2013J      resource
# ...       ...         ...               ...           ...
# 6359   897063         GGG             2014J      resource
# 6360   897109         GGG             2014J      resource
# 6361   896965         GGG             2014J     oucontent
# 6362   897060         GGG             2014J      resource
# 6363   897100         GGG             2014J      resource
#
# [6364 rows x 4 columns]

# %%
#Label Encoding
labelencoder = LabelEncoder()
vle['code_module'] = labelencoder.fit_transform(vle['code_module'])
vle['code_presentation'] = labelencoder.fit_transform(vle['code_presentation'])
vle['activity_type'] = labelencoder.fit_transform(vle['activity_type'])
vle['week_from'] = labelencoder.fit_transform(vle['week_from'])
vle['week_to'] = labelencoder.fit_transform(vle['week_to'])

# %%
vle
# Out:
#       id_site  code_module  code_presentation  activity_type  week_from  \
# 0      546943            0                  1             16         30
# 1      546712            0                  1              9         30
# 2      546998            0                  1             16         30
# 3      546888            0                  1             19         30
# 4      547035            0                  1             16         30
# ...       ...          ...                ...            ...        ...
# 6359   897063            6                  3             16         30
# 6360   897109            6                  3             16         30
# 6361   896965            6                  3              9         30
# 6362   897060            6                  3             16         30
# 6363   897100            6                  3             16         30
#
#       week_to
# 0          30
# 1          30
# 2          30
# 3          30
# 4          30
# ...
